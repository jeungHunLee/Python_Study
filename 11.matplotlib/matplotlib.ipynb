# %%
"""선그래프 그리기"""
import matplotlib.pyplot as plt

data = [50, 125, 300, 150, 400]

plt.plot(range(len(data)), data)    # x값, y값
plt.show()

# %%
"""곡선 그래프 그리기"""
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3 * np.pi, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
"""막대 그래프 그리기"""
import matplotlib.pyplot

data = [50, 125, 300, 150, 400]

plt.bar(range((len(data))), data)
plt.show()

# %%
"""scatter point"""
import numpy as np
import matplotlib.pyplot

p = np.random.rand(100, 2)    # 100행 2열 실수

plt.scatter(p[:, 0], p[:, 1])
plt.show()

# %%
"""pie 그래프"""
import matplotlib.pyplot as plt
import numpy as np

labels = ['SamSung', 'Huawei', 'Apple', 'Xiaomi', 'Oppo', 'Etc']
sizes = [20.4, 15.8, 10.5, 9, 7.6, 36.7]
explode = (0.3, 0, 0, 0, 0, 0)    # 돌출 정도

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.show()

# %%
"""이미지 그리기"""
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("lena.jpg", cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("Title")
plt.xlabel('automatic generation')    # x축 레이블
plt.ylabel('numbers')    # y축 레이블
plt.plot([1, 2, 3, 4])    # x축은 0, 1, 2...
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b", lw=4, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
"""c(라인 색생), lw(line width), ls(line style), marker, ms(marker size), mec(markeredgecolor), mew(markeredgewidth), mfc(makerfacecolor)"""
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.plot(x, c)
plt.xticks([-np.pi, -np.pi / 2, np.pi / 2, np.pi])    # x축 눈금 설정
plt.yticks([-1, 0, 1])    # y축 눈금 설정
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])    # [xmin, xmax, ymin, ymax]
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 256)
c, s = np.cos(x), np.sin(x)
plt.plot(x, c, ls="--", label="cosine")    # label: cosine
plt.plot(x, s, ls=":", label="sine")    # label: sine
plt.legend(loc=2)    # 2번 위치
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t ** 2, 'bs', t, t ** 3, 'g^')
plt.show()

# %%
import matplotlib.pyplot as plt

data = [50, 125, 300, 150, 400]
line = plt.plot(range(len(data)), data, '--')     # plt 객체 저장 후
plt.setp(line, color='r', lw=2.0)    # 저장된 객체에 대하여 속성 제어
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2 * np.pi * t)

t1 = np.arange(0., 5., 0.1)
t2 = np.arange(0., 5., 0.02)

plt.figure(1)
plt.subplot(211)    # 2행 1열 1번
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(2, 1, 2)    # 2행 1열 2번
plt.plot(t2, np.cos(2 * np.pi * t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(1)
plt.subplot(2, 1, 1)    # 2행 1열 1번째
plt.plot([1, 2, 3])
plt.subplot(2, 1, 2)
plt.plot([4, 5, 6])

plt.figure(2)
plt.plot([4, 5, 6])

plt.figure(1)
plt.subplot(2, 1, 1)
plt.title("Easy as 1, 2, 3")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# GridSpec: subplot이 들어갈 위치의 그리드
grid = plt.GridSpec(2, 3, wspace=0.5, hspace=0.3)    # nrows, ncols, 좌우간격, 상하간격
ax1 = plt.subplot(grid[0, 0])
ax2 = plt.subplot(grid[0, 1:])
ax3 = plt.subplot(grid[1, :2])
ax4 = plt.subplot(grid[1, 2])

ax1.plot(np.arange(10))
x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
ax2.plot(np.sin(x))
ax3.plot(np.cos(x))
ax4.bar(np.arange(10), np.random.randint(0, 100, 10))
plt.show()
