# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.relplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style='whitegrid')
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips)    # smoker 기준으로 계열화
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.relplot(x='total_bill', y='tip', hue='smoker', style='time', data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style='whitegrid')
sns.relplot(x='total_bill', y='tip', hue='smoker', style='size', data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.relplot(x='sepal_length', y='petal_length', kind='line', data=iris)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.relplot(x='sepal_length', y='petal_length', kind='line', ci=None, data=iris)    # 평균과 95% 신뢰 구간 삭제
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.relplot(x='sepal_length', y='petal_length', kind='line', hue='species', data=iris)    # species 기준으로 계열화
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

titanic = sns.load_dataset('titanic')

sns.set_theme(style="whitegrid")
sns.countplot(x='class', hue='who', data=titanic)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.countplot(x='size', hue='day', data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.displot(data=iris, y='petal_length')    # 가로로 출력
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style='whitegrid')
sns.displot(iris, x='petal_length', binwidth=0.3)    # binwidth: 막대 두께
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.displot(data=iris, x="petal_length", hue="species")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.displot(iris, x="petal_length", hue="species", multiple="stack")
sns.displot(iris, x="petal_length", hue="species", multiple="layer")
sns.displot(iris, x="petal_length", hue="species", multiple="dodge")
sns.displot(iris, x="petal_length", hue="species", multiple="fill")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.displot(iris, x="petal_length", hue="species", kde=True)    # 밀도 표시
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.displot(iris, x="petal_length", hue="species", kind="kde")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.displot(iris, x="petal_length", kind="ecdf", hue="species")    # 누적분포도
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.displot(iris, x="petal_length", y="sepal_length", hue="species")    # 꽃잎 길이와 꽃받침 길이 간 분포
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.displot(iris, x="petal_length", y="sepal_length", hue="species", kind="kde")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.pairplot(tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset('iris')

sns.set_theme(style="whitegrid")
sns.pairplot(iris, hue="species")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

isis = sns.load_dataset('iris')

sns.set(style="whitegrid")
sns.pairplot(iris, vars=["sepal_width", "sepal_length"])    # 원하는 column만 가져오기
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set(style="whitegrid")
sns.lmplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.lmplot(x="total_bill", y="tip", row="sex", col="time", data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.set_theme(style="whitegrid")
sns.jointplot(data=tips, x="total_bill", y="tip", kind="kde")
plt.show()
